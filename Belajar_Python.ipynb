# %% [markdown]
# # Sum Operator

# %%
x = int(input())

# %%
y = int(input())

# %%
print(x + y)

# %% [markdown]
# # Exponent Operator

# %%
x = int(input()) # jika tidak dibungkus int() maka hasil dari input() adalah string

# %%
y = x**x

# %%
print(y)

# %% [markdown]
# # Floor division

# %%
a = 100

# %%
b = 4

# %%
print(a // b)

# %% [markdown]
# # Array / List

# %%
mylist = ['Indra', 'Damar', 'Jati', 21, 8, 2002]

# %%
mylist[2] # dihitung dari index 0

# %%
mylist = ['Indra', 21, 8, 2002]

# %%
mylist[0:3]

# %%
len(mylist) # len() berguna untuk menghitung jumlah value di dalam array/list

# %%
mylist.count('Indra') # count(query) berguna untuk menghitung dan mencari jumlah value dalam list

# %%
mylist[-3:-1]

# %%
mylist.append('Damar')

# %%
print(mylist)

# %%
mylist.insert(1, 'Damar')

# %%
print(mylist)

# %%
nama = ['Indra', 'Damar', 'Jati']

# %%
ttl = [21, 8, 2002]

# %%
mylist = nama + ttl

# %%
print(mylist)

# %%
mylist.insert(1, nama)

# %%
print(mylist)

# %%
"Indra" in mylist

# %%
"indra" in mylist

# %%
21 in mylist

# %%
"Ganteng" in mylist

# %%
alphabeth = ['a', 'c', 'e', 'g', 'b', 'd', 'f', 'z', 'y', 'x'] # sort() berguna untuk mengurutkan angka dan huruf di dalam list

# %%
alphabeth.sort()

# %%
alphabeth

# %%
numbers = [1, 9, 0, 4, 6, 8, 3, 2, 5, 7, 101, 99, 55]

# %%
numbers.sort()

# %%
numbers

# %% [markdown]
# ## Quiz

# %% [markdown]
# Lets say our expense (pengeluaran) for every month are listed below:

# %% [markdown]
# - January: 2200
# - February: 2350
# - March: 2600
# - April: 2130
# - May: 2190

# %% [markdown]
# Create list to store these monthly expenses:

# %% [markdown]
# - In Feb, how many dollars you spent extra compare to January?
# - Find out your total expenses in first quarter (first three months) of the year
# - Find out if you spent exactly 2000 dollars in any month
# - June month is just finished, and your expenses is 1980 dollar, add it to our month expenses list
# - Kamu dapat kembalian dari barang yang kamu beli di bulan April dan dapat refund sebesar 200 dollar. make correction to your monthly expenses list based on this.

# %% [markdown]
# ### Jawaban

# %%
expenses = [2200, 2350, 2600, 2130, 2190]

# %%
print(expenses[0] - expenses[1]) # 1. Spent extra compared to January

# %%
print(expenses[0] + expenses[1] + expenses[2]) # 2. Total expenses in first quarter

# %%
2000 in expenses # 3. Find out if you spent exactly 2000 dollars in any month

# %%
expenses.append(1980) # 4. Add June expense to Monthly expenses

# %%
expenses[3] + 200

# %% [markdown]
# # Tuples

# %% [markdown]
# Tuple itu sama persis dengan list/array, perbedaannya adalah, Tuple bersifat immutable, yang mana setelah kita membuat Tuple, kita tidak bisa mengganti value di dalamnya, jadinya permanen.

# %%
x = (8, 3, 7, 2, 5, 4, 6, 9, 9)

# %%
x[0: 3]

# %%
x.sort() # ini akan menghasilkan error, karena, Tuple bersifat immutable (permanen)

# %%
x.count(9) # perintah count() tidak akan menghasilkan error, karena tidak mengubah isi value dari tuple tersebut
# Out:
# 2

# %%
y = ('Indra', 'Damar', 'Jati')

# %%
z = x + y

# %%
z # ini bisa terjadi, karena, ini tidak mengubah value tuple asal, yaitu x dan y
# Out:
# (8, 1, 3, 7, 2, 5, 4, 6, 9, 9, 'Indra', 'Damar', 'Jati')

# %%
a = ('Indra', 9 ) * 5 # Membuat perulangan

# %%
a
# Out:
# ('Indra', 9, 'Indra', 9, 'Indra', 9, 'Indra', 9, 'Indra', 9)

# %%
min(x) # min() untuk mencari value terkecil
# Out:
# 2

# %%
max(x) # max() untuk mencari value terbesar
# Out:
# 9

# %%
del a # del untuk menghapus tuple

# %% [markdown]
# # Dictionaries / Object

# %%
d = {}

# %%
d['Indra'] = 21 # Mengisi Dictionary

# %%
d['Damar'] = 8

# %%
d['Jati'] = 2002

# %%
d[21] = 'Indra'

# %%
d[8] = 'Damar'

# %%
d[2002] = 'Jati'

# %%
d['Indra'] # Pemanggilan dict
# Out:
# 200

# %%
d[21] # Pemanggilan dict
# Out:
# 'Indra'

# %%
for key, value in d.items(): # Perulangan untuk Dictionary
  print('Key: ')
  print(key)
  print('Value: ')
  print(value)
  print('')
# Out:
# Key:
# Indra
# Value:
# 200
#
# Key:
# Damar
# Value:
# 210
#
# Key:
# Jati
# Value:
# 2002
#
# Key:
# 21
# Value:
# Indra
#
# Key:
# 8
# Value:
# Damar
#
# Key:
# 2002
# Value:
# Jati
